# %%
import numpy as np
import pandas as pd
import os, math

from sklearn.svm import NuSVR
from sklearn.preprocessing import StandardScaler

# %%
# Read xlsx files
Y = pd.read_excel('BRCA.subsample.xlsx', sheet_name = 0)
X = pd.read_excel('LM22Signature.xlsx', sheet_name = 0)

# %%
mean = X.iloc[:, 1:].mean()
std = X.iloc[:, 1:].stack().std()
X.iloc[:, 1:] = (X.iloc[:, 1:] - mean.mean()) / std
    
# Intersection between X and Y
X = X.loc[X['Gene symbol'].isin(Y['Gene symbol'])]
Y = Y.loc[Y['Gene symbol'].isin(X['Gene symbol'])]
    
# Ordering by GeneSymbol
X = X.sort_values(by=['Gene symbol'])
Y = Y.sort_values(by=['Gene symbol'])

# Slice Gene symbol column
X = X.iloc[:, 1:]
Y = Y.iloc[:, 1:]
X.reset_index(drop=True, inplace=True)
    
# Normalize features Matrix
scaler = StandardScaler()
scaler.fit(Y)
Yn = pd.DataFrame(scaler.transform(Y.values), columns=Y.columns, index=Y.index)

# %%
wsel = [1 for x in range(len(X.columns))]
wsel = pd.DataFrame(wsel, X.columns).T

# %%
# Run NuSVR
clf = NuSVR(kernel='linear', C=1.0, nu=0.25)
clf.fit(X, Y.iloc[:,1])
d = [[1, clf]]
listNuSvr = pd.DataFrame(d, columns=['RMSEpred', 'model'])

# %%
model = listNuSvr.iloc[0]['model']

# Get betas
w = model.coef_

# Set values i to zero where i < 0
w = np.where(w<0, 0, w)
absW = w
        
# Normalize data
w = w/np.sum(w)
        
# Set values i to zero where i < delta
w = np.where(w<0.007, 0, w)

wa = pd.DataFrame(w[0], X.columns).T
wsel
# Out:
#    B cells naive  B cells memory  Plasma cells  T cells CD8  \
# 0              1               1             1            1
#
#    T cells CD4 naive  T cells CD4 memory resting  \
# 0                  1                           1
#
#    T cells CD4 memory activated  T cells follicular helper  \
# 0                             1                          1
#
#    T cells regulatory (Tregs)  T cells gamma delta  ...  Monocytes  \
# 0                           1                    1  ...          1
#
#    Macrophages M0  Macrophages M1  Macrophages M2  Dendritic cells resting  \
# 0               1               1               1                        1
#
#    Dendritic cells activated  Mast cells resting  Mast cells activated  \
# 0                          1                   1                     1
#
#    Eosinophils  Neutrophils
# 0            1            1
#
# [1 rows x 22 columns]

# %%
wa.loc[:, (wa.values > 0.007).any(axis=0)]
# Out:
#    B cells naive  B cells memory  T cells CD8  T cells follicular helper  \
# 0       0.011085        0.014853     0.119297                   0.116703
#
#    T cells regulatory (Tregs)  NK cells resting  NK cells activated  \
# 0                    0.111978          0.010844            0.035352
#
#    Macrophages M0  Macrophages M1  Macrophages M2  Dendritic cells activated  \
# 0        0.297321        0.125586        0.083635                   0.020884
#
#    Mast cells resting
# 0            0.052461

# %%
# wsel.loc[wsel.columns.isin(wa.loc[:, (wa.values > 0.007).any(axis=0)].columns)]
wsel.loc[:, wsel.columns.isin(wa.loc[:, (wa.values > 0.007).any(axis=0)].columns)]
# Out:
#    B cells naive  B cells memory  T cells CD8  T cells follicular helper  \
# 0              1               1            1                          1
#
#    T cells regulatory (Tregs)  NK cells resting  NK cells activated  \
# 0                           1                 1                   1
#
#    Macrophages M0  Macrophages M1  Macrophages M2  Dendritic cells activated  \
# 0               1               1               1                          1
#
#    Mast cells resting
# 0                   1

# %%
wa.loc[:, (wa.values > 0.007).any(axis=0)].columns
# Out:
# Index(['B cells naive', 'B cells memory', 'T cells CD8',
#        'T cells follicular helper', 'T cells regulatory (Tregs)',
#        'NK cells resting', 'NK cells activated', 'Macrophages M0',
#        'Macrophages M1', 'Macrophages M2', 'Dendritic cells activated',
#        'Mast cells resting'],
#       dtype='object')

# %%
# Checking if all the values are NaN
if w.isnull().all().all():
    print('todos nulos')
        
# Checking if any value is < delta
if w.apply(lambda x: x < 0.007).any().any():
    if(w.apply(lambda x: x > 0).sum().sum() == 1):
        print('la suma da 1')
    else:
        wsel.loc[-wsel.columns.isin(w.columns[w.values >= 0.007])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-155-b172af13c3c8> in <module>
#       8         print('la suma da 1')
#       9     else:
# ---> 10         wsel.loc[-wsel.columns.isin(w.columns[w.values >= 0.007])] = 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in __getitem__(self, key)
#     588
#     589         # fall back to Int64Index
# --> 590         return super_getitem(key)
#     591
#     592     def __floordiv__(self, other):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3967
#    3968         key = com.values_from_object(key)
# -> 3969         result = getitem(key)
#    3970         if not is_scalar(result):
#    3971             return promote(result)
#
# IndexError: too many indices for array

# %%
XX = X.loc[:, X.columns.isin(wsel2.columns[wsel2.values[0] > 0])]
XX
# Out:
#      B cells memory  Plasma cells  T cells CD8  T cells CD4 naive  \
# 0         -0.285381     -0.286867    -0.288098          -0.287974
# 1         -0.280587     -0.013955    -0.279688          -0.274853
# 2         -0.154080     -0.273609     0.155926           0.466139
# 3         -0.282887     -0.280575    -0.284247          -0.278436
# 4          0.527425      0.183164    -0.160546           0.024591
# 5          0.194997     -0.152746    -0.280336          -0.272999
# 6         -0.155408     -0.235871    -0.271075          -0.255723
# 7         -0.245127     -0.258521    -0.272015          -0.256451
# 8         -0.074483     -0.167521     0.090053          -0.257333
# 9         -0.281336     -0.280640     0.023814           0.013592
# 10         1.627151      0.313913    -0.165542          -0.265811
# 11        -0.284110     -0.286087    -0.285790          -0.282082
# 12         0.734582     -0.209531    -0.256686          -0.258271
# ...
