# %%
from cmapPy.pandasGEXpress.parse import parse

# %%
df = parse('data/CCLE_RNAseq_genes_counts_20180929.gct')

# %%
df.data_df
# Out:
# cid                22RV1_PROSTATE  2313287_STOMACH  253JBV_URINARY_TRACT  \
# rid
# ENSG00000223972.4            12.0              8.0                   8.0
# ENSG00000227232.4          1340.0            821.0                 678.0
# ENSG00000243485.2             4.0              1.0                   3.0
# ENSG00000237613.2             6.0              3.0                   2.0
# ENSG00000268020.2             0.0              2.0                   3.0
# ...                           ...              ...                   ...
# ENSG00000198695.2        124017.0         112857.0              136078.0
# ENSG00000210194.1            42.0             23.0                  11.0
# ENSG00000198727.2        695276.0         457726.0              250709.0
# ENSG00000210195.2             2.0              0.0                   5.0
# ENSG00000210196.2             4.0              2.0                  11.0
#
# cid                253J_URINARY_TRACT  42MGBA_CENTRAL_NERVOUS_SYSTEM  \
# rid
# ...
