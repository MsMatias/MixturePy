# %%
import pandas as pd
import numpy as np

# %%
X = pd.read_excel('app/data/outputCellines(2).xlsx', sheet_name = 1) 
X.index = X.iloc[:,0].astype(int)
X.index.name = 'Subjects'
result3 = X.iloc[:, 1:]

# %%
result3
# Out:
#           B cells naive  B cells memory  Plasma cells  T cells CD8  \
# Subjects
# 906826         0.000000             0.0      0.345776          0.0
# 687983         0.000000             0.0      0.000000          0.0
# 910927              NaN             NaN           NaN          NaN
# 1240138        0.000000             0.0      0.000000          0.0
# 1240139        0.000000             0.0      0.087772          0.0
# ...                 ...             ...           ...          ...
# 1298157        0.229618             0.0      0.286891          0.0
# 1480372        0.179031             0.0      0.000000          0.0
# 1298533        0.026337             0.0      0.083086          0.0
# 930299         0.043072             0.0      0.000000          0.0
# 905954         0.000000             0.0      0.000000          0.0
#
#           T cells CD4 naive  T cells CD4 memory resting  \
# Subjects
# 906826             0.000000                    0.437601
# ...

# %%
df = result3.sum(axis=1).where(df > 0).notna()
df
# Out:
# Subjects
# 906826      True
# 687983      True
# 910927     False
# 1240138     True
# 1240139     True
#            ...
# 1298157     True
# 1480372     True
# 1298533     True
# 930299      True
# 905954      True
# Length: 1018, dtype: bool

# %%
result3[df]
# Out:
#           B cells naive  B cells memory  Plasma cells  T cells CD8  \
# Subjects
# 906826         0.000000             0.0      0.345776          0.0
# 687983         0.000000             0.0      0.000000          0.0
# 1240138        0.000000             0.0      0.000000          0.0
# 1240139        0.000000             0.0      0.087772          0.0
# 906792         0.000000             0.0      0.262769          0.0
# ...                 ...             ...           ...          ...
# 1298157        0.229618             0.0      0.286891          0.0
# 1480372        0.179031             0.0      0.000000          0.0
# 1298533        0.026337             0.0      0.083086          0.0
# 930299         0.043072             0.0      0.000000          0.0
# 905954         0.000000             0.0      0.000000          0.0
#
#           T cells CD4 naive  T cells CD4 memory resting  \
# Subjects
# 906826             0.000000                    0.437601
# ...
