# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
readRDS = robjects.r['readRDS']

# %%
df = readRDS('./data/betas.list.rds')
df = pandas2ri.ri2py(df)

# %%
from rpy2.robjects.packages import importr

# %%
utils = importr('utils')
base = importr('base')
utils.install_packages('BiocManager')
# Out:
# rpy2.rinterface.NULL

# %%
biocmanager = importr('BiocManager')
biocmanager.install('limma')
limma = importr('limma')
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-9-5e3e3d8360d6> in <module>
#       1 biocmanager = importr('BiocManager')
# ----> 2 biocmanager.install('limma')
#       3 limma = importr('limma')
#
# c:\users\miriam\miniconda3\lib\site-packages\rpy2-2.9.4-py3.7-win-amd64.egg\rpy2\robjects\functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# c:\users\miriam\miniconda3\lib\site-packages\rpy2-2.9.4-py3.7-win-amd64.egg\rpy2\robjects\functions.py in __call__(self, *args, **kwargs)
#     104         for k, v in kwargs.items():
#     105             new_kwargs[k] = conversion.py2ri(v)
# --> 106         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     107         res = conversion.ri2ro(res)
#     108         return res
#
# RRuntimeError: Error in if (answer %in% allowed) break : argument is of length zero

# %%
df = readRDS('./data/BRCA_rna.rds')
df = pandas2ri.ri2py(df)

# %%
df
# Out:
# R object with classes: ('EList',) mapped to:
# <ListVector - Python:0x0000000111DB90C8 / R:0x0000000111E0C1A0>
# [Matrix, DataFrame, DataFrame]
#   E: <class 'rpy2.robjects.vectors.Matrix'>
#   R object with classes: ('matrix',) mapped to:
# <Matrix - Python:0x0000000111E79D08 / R:0x00007FF7946A0010>
# [571.840000, 0.000000, 0.000000, 298.740000, ..., 1648.000000, 9778.000000, 1622.000000, 1328.000000]
# R object with classes: ('EList',) mapped to:
# <ListVector - Python:0x0000000111DB90C8 / R:0x0000000111E0C1A0>
# [Matrix, DataFrame, DataFrame]
# R object with classes: ('EList',) mapped to:
# <ListVector - Python:0x0000000111DB90C8 / R:0x0000000111E0C1A0>
# [Matrix, DataFrame, DataFrame]

# %%
df[1]
# Out:
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D0251548 / R:0x00000006D0888148>
# [FloatVector, IntVector, Matrix]
#   beta: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x00000006D8D550C8 / R:0x00000006CF0157C8>
# [0.231124, 0.000000, 0.000000, 0.000000, ..., 0.000000, 0.300709, 0.000000, 0.000000]
#   id: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x00000006CCBB0F88 / R:0x00000006D08880F8>
# [20, 6, 1, 7, 18]
#   A: <class 'rpy2.robjects.vectors.Matrix'>
#   R object with classes: ('matrix',) mapped to:
# <Matrix - Python:0x00000006D017AA48 / R:0x00000006D8D79F30>
# [142.072478, 25.912689, 305.701176, 32.632942, ..., 75.212158, 271.793550, 32.073927, 16.340898]

# %%
df
# Out:
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# ...
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x00000006D6E97A48 / R:0x00000006D088D698>
# [ListVector, ListVector, ListVector, ListVector, ..., ListVector, ListVector, ListVector, ListVector]

# %%
len(df)
# Out:
# 1000
